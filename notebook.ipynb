# %%
import sys
print("Python Path:", sys.executable)
print("Version    :", sys.version)
# Out:
# Python Path: /Users/johnkilima/Documents/projects/training/llm-zoomcamp-2026-code/.venv/bin/python
# Version    : 3.12.6 (v3.12.6:a4a2d2b0d85, Sep  6 2024, 16:08:03) [Clang 13.0.0 (clang-1300.0.29.30)]

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from openai import OpenAI
openai_client = OpenAI(
    api_key="MOONSHOOT_API_KEY",
)
